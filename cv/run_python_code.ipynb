# %% [markdown]
# Google Driveを使えるようにする

# %%
from google.colab import drive

# %%
drive.mount('/content/drive',  force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# カレントディレクトリを確認する

# %%
pwd
# Out:
# '/content'

# %% [markdown]
# 対象のディレクトリに移動する（"/content/drive/My Drive/" があなたのドライブのホームディレクトリ）
#
# この例の場合，ホームにAI_Experimentというフォルダを作り，その下にダウンロードしたフォルダを配置している

# %%
cd /content/drive
# Out:
# /content/drive

# %%
cd MyDrive/
# Out:
# /content/drive/MyDrive

# %%
cd Day2
# Out:
# /content/drive/MyDrive/ai_practice/Day2

# %% [markdown]
# 試しにPythonコードを実行する

# %%
! python train_mnist_mlp.py -g 0
# Out:
# GPU: 0
# # unit: 1000
# # Minibatch-size: 100
# # epoch: 20
#
# [epoch 1] loss: 1055.803
# [epoch 2] loss: 423.126
# [epoch 3] loss: 257.667
# [epoch 4] loss: 212.240
# [epoch 5] loss: 190.474
# [epoch 6] loss: 176.709
# [epoch 7] loss: 166.192
# [epoch 8] loss: 157.612
# [epoch 9] loss: 150.360
# [epoch 10] loss: 144.014
# [epoch 11] loss: 137.950
# [epoch 12] loss: 132.240
# [epoch 13] loss: 127.092
# [epoch 14] loss: 122.271
# [epoch 15] loss: 117.658
# [epoch 16] loss: 113.411
# [epoch 17] loss: 109.253
# [epoch 18] loss: 105.220
# [epoch 19] loss: 101.538
# [epoch 20] loss: 98.100
# Finished Training

# %%
! pip3 install gym
! pip3 install pyworld
! pip3 install pysptk
! pip3 install dtw
# Out:
# Requirement already satisfied: gym in /usr/local/lib/python3.7/dist-packages (0.17.3)
# Requirement already satisfied: pyglet<=1.5.0,>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from gym) (1.5.0)
# Requirement already satisfied: cloudpickle<1.7.0,>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from gym) (1.3.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from gym) (1.4.1)
# Requirement already satisfied: numpy>=1.10.4 in /usr/local/lib/python3.7/dist-packages (from gym) (1.19.5)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from pyglet<=1.5.0,>=1.4.0->gym) (0.16.0)
# Collecting pyworld
#   Downloading pyworld-0.3.0.tar.gz (212 kB)
#      |████████████████████████████████| 212 kB 6.7 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: cython>=0.24.0 in /usr/local/lib/python3.7/dist-packages (from pyworld) (0.29.24)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from pyworld) (1.19.5)
# Building wheels for collected packages: pyworld
#   Building wheel for pyworld (PEP 517) ... done
#   Created wheel for pyworld: filename=pyworld-0.3.0-cp37-cp37m-linux_x86_64.whl size=609633 sha256=96b03a6c181275641486bbec6d7fff5ae27d2e3575455430a4c43ae8ed3d702c
#   Stored in directory: /root/.cache/pip/wheels/e7/7c/11/c775fffa0e1e7b05a6604b4323408a77f80fb4ab304d96b5c6
# Successfully built pyworld
# Installing collected packages: pyworld
# Successfully installed pyworld-0.3.0
# Collecting pysptk
#   Downloading pysptk-0.1.18.tar.gz (419 kB)
#      |████████████████████████████████| 419 kB 5.3 MB/s
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from pysptk) (1.4.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from pysptk) (1.15.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from pysptk) (4.4.2)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.7/dist-packages (from scipy->pysptk) (1.19.5)
# Building wheels for collected packages: pysptk
#   Building wheel for pysptk (setup.py) ... done
#   Created wheel for pysptk: filename=pysptk-0.1.18-cp37-cp37m-linux_x86_64.whl size=951726 sha256=5cdf4328b1e963205baefefd3610a6835ed952eb67bb39f9b8b123348d0f4b7d
#   Stored in directory: /root/.cache/pip/wheels/44/95/38/580fe995213257289c69bf74f4d122e39cd134c731fe17a5a6
# Successfully built pysptk
# Installing collected packages: pysptk
# Successfully installed pysptk-0.1.18
# Collecting dtw
#   Downloading dtw-1.4.0.tar.gz (4.7 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from dtw) (1.19.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from dtw) (1.4.1)
# Building wheels for collected packages: dtw
#   Building wheel for dtw (setup.py) ... done
#   Created wheel for dtw: filename=dtw-1.4.0-py3-none-any.whl size=5315 sha256=7169e7dfbe7fbe862a199808527315fcf88bb5f73f53e819f4c9e4ce613f6cb7
#   Stored in directory: /root/.cache/pip/wheels/f9/51/54/b7f446e6d4f5be9a66066b59c5030731191260515737be4496
# Successfully built dtw
# Installing collected packages: dtw
# Successfully installed dtw-1.4.0

# %%
ls
# Out:
# nlp/  rl/

# %%
cd nlp
# Out:
# /content/drive/MyDrive/ai_practice/Day2/nlp

# %%
! python language_model_rnn_train.py
# Out:
# 1 / 10 epoch start.
# 100 / 1000 sentences finished.
# 200 / 1000 sentences finished.
# 300 / 1000 sentences finished.
# 400 / 1000 sentences finished.
# 500 / 1000 sentences finished.
# 600 / 1000 sentences finished.
# 700 / 1000 sentences finished.
# 800 / 1000 sentences finished.
# 900 / 1000 sentences finished.
# 1000 / 1000 sentences finished.
# mean loss = 49.745354524850846.
# 2 / 10 epoch start.
# 100 / 1000 sentences finished.
# 200 / 1000 sentences finished.
# 300 / 1000 sentences finished.
# 400 / 1000 sentences finished.
# 500 / 1000 sentences finished.
# 600 / 1000 sentences finished.
# 700 / 1000 sentences finished.
# 800 / 1000 sentences finished.
# 900 / 1000 sentences finished.
# 1000 / 1000 sentences finished.
# mean loss = 39.593942521333695.
# 3 / 10 epoch start.
# 100 / 1000 sentences finished.
# 200 / 1000 sentences finished.
# 300 / 1000 sentences finished.
# 400 / 1000 sentences finished.
# 500 / 1000 sentences finished.
# 600 / 1000 sentences finished.
# 700 / 1000 sentences finished.
# 800 / 1000 sentences finished.
# 900 / 1000 sentences finished.
# 1000 / 1000 sentences finished.
# mean loss = 34.384980751752856.
# 4 / 10 epoch start.
# 100 / 1000 sentences finished.
# 200 / 1000 sentences finished.
# 300 / 1000 sentences finished.
# 400 / 1000 sentences finished.
# 500 / 1000 sentences finished.
# 600 / 1000 sentences finished.
# 700 / 1000 sentences finished.
# 800 / 1000 sentences finished.
# 900 / 1000 sentences finished.
# 1000 / 1000 sentences finished.
# mean loss = 29.657704899549483.
# 5 / 10 epoch start.
# 100 / 1000 sentences finished.
# 200 / 1000 sentences finished.
# 300 / 1000 sentences finished.
# 400 / 1000 sentences finished.
# 500 / 1000 sentences finished.
# 600 / 1000 sentences finished.
# 700 / 1000 sentences finished.
# 800 / 1000 sentences finished.
# 900 / 1000 sentences finished.
# 1000 / 1000 sentences finished.
# mean loss = 25.255020861148836.
# 6 / 10 epoch start.
# 100 / 1000 sentences finished.
# 200 / 1000 sentences finished.
# 300 / 1000 sentences finished.
# 400 / 1000 sentences finished.
# 500 / 1000 sentences finished.
# 600 / 1000 sentences finished.
# 700 / 1000 sentences finished.
# 800 / 1000 sentences finished.
# 900 / 1000 sentences finished.
# 1000 / 1000 sentences finished.
# mean loss = 21.216237169265746.
# 7 / 10 epoch start.
# 100 / 1000 sentences finished.
# 200 / 1000 sentences finished.
# 300 / 1000 sentences finished.
# 400 / 1000 sentences finished.
# 500 / 1000 sentences finished.
# 600 / 1000 sentences finished.
# 700 / 1000 sentences finished.
# 800 / 1000 sentences finished.
# 900 / 1000 sentences finished.
# 1000 / 1000 sentences finished.
# mean loss = 17.62396141934395.
# 8 / 10 epoch start.
# 100 / 1000 sentences finished.
# 200 / 1000 sentences finished.
# 300 / 1000 sentences finished.
# 400 / 1000 sentences finished.
# 500 / 1000 sentences finished.
# 600 / 1000 sentences finished.
# 700 / 1000 sentences finished.
# 800 / 1000 sentences finished.
# 900 / 1000 sentences finished.
# 1000 / 1000 sentences finished.
# mean loss = 14.649403183475137.
# 9 / 10 epoch start.
# 100 / 1000 sentences finished.
# 200 / 1000 sentences finished.
# 300 / 1000 sentences finished.
# 400 / 1000 sentences finished.
# 500 / 1000 sentences finished.
# 600 / 1000 sentences finished.
# 700 / 1000 sentences finished.
# 800 / 1000 sentences finished.
# 900 / 1000 sentences finished.
# 1000 / 1000 sentences finished.
# mean loss = 12.237428118743003.
# 10 / 10 epoch start.
# 100 / 1000 sentences finished.
# 200 / 1000 sentences finished.
# 300 / 1000 sentences finished.
# 400 / 1000 sentences finished.
# 500 / 1000 sentences finished.
# 600 / 1000 sentences finished.
# 700 / 1000 sentences finished.
# 800 / 1000 sentences finished.
# 900 / 1000 sentences finished.
# 1000 / 1000 sentences finished.
# mean loss = 10.25327561216429.

# %%
! python language_model_rnn_test.py
# Out:
# python3: can't open file 'language_model_rnn_test.py': [Errno 2] No such file or directory

# %%
! python
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-0b2c1959a744> in <module>()
# ----> 1 私
#
# NameError: name '私' is not defined
